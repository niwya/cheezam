# %%
from google_images_download import google_images_download

# %%
chromedriver_path = r"C:\Users\chloe\Documents\IIT\Classes\Spring2021\MMAE500\Project\chromedriver.exe"

# %%
response = google_images_download.googleimagesdownload()   #class instantiation
arguments = {"keywords":"raw mozzarella, mozzarella en boule","limit":400,"print_urls":True, "chromedriver":chromedriver_path}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
# Out:
# Item no.: 1 --> Item name = raw mozzarella
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://wholelifestylenutrition.com/wp-content/uploads/pic013.jpg
# Completed Image ====> 1.pic013.jpg
# Image URL: https://www.seriouseats.com/images/2015/10/20151017-pies-vicky-wasik-2-1500x1125.jpg
# URLError on an image...trying next one... Error: HTTP Error 404: Not Found
# Image URL: http://cdn.shopify.com/s/files/1/2836/2982/products/mozzarella-cheese_grande.jpg?v=1529434174
# Completed Image ====> 2.mozzarella-cheese_grande.jpg
# Image URL: https://eatup.kitchen/wp-content/uploads/2017/04/DSCF7574.jpg
# Completed Image ====> 3.dscf7574.jpg
# Image URL: https://i.pinimg.com/originals/62/7f/f5/627ff5c908c883a42a723bb6ebb8e314.jpg
# Completed Image ====> 4.627ff5c908c883a42a723bb6ebb8e314.jpg
# Image URL: https://i1.wp.com/greenevi.com/wp-content/uploads/2017/04/greenevi-cashew-mozzarella.jpg?ssl=1
# ...
